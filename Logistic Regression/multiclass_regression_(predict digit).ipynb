# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import numpy as np

plt.gray()
digits = load_digits()
# print(dir(digits))
# print(digits.images[0])
# print(digits.target)
# plt.matshow(digits.images[9])
x = digits.data
y = digits.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.02)
model = LogisticRegression()
model.fit(x_train, y_train)
# model.score(x_test, y_test)


# for i in x_test.reshape(1,36, 64):
#     plt.matshow(i)
    

# print(digits.data[0])
# print(np.array(digits.data[0].reshape(8,8)))
# print(digits.images[0])
# plt.matshow(digits.images[0])
# plt.matshow(np.array(digits.data[0].reshape(8,8)))

predict = model.predict(x_test)
for i in range(9):
    print(predict[i])
    plt.matshow(np.array(x_test[i].reshape(8,8)))
# Out:
# C:\Users\prith\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 8
# 4
# 4
# 4
# 1
# 6
# 2
# 7
# 6
